# %%
import pandas as pd
import numpy as np

df = pd.read_csv("household_power_consumption.txt", sep=";")

df.replace("?", np.nan, inplace=True)

df["Global_active_power"] = pd.to_numeric(df["Global_active_power"])

df["datetime"] = pd.to_datetime(df["Date"] + " " + df["Time"])

df = df.set_index("datetime")

df = df.dropna()
# Out:
# C:\Users\anush\AppData\Local\Temp\ipykernel_19384\3620562067.py:4: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("household_power_consumption.txt", sep=";")
# C:\Users\anush\AppData\Local\Temp\ipykernel_19384\3620562067.py:10: UserWarning: Parsing dates in %d/%m/%Y %H:%M:%S format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["datetime"] = pd.to_datetime(df["Date"] + " " + df["Time"])

# %%
power = df["Global_active_power"]

daily_power = power.resample("D").sum()

# %%
last_30_days = daily_power[-30:]

# %%
import joblib

joblib.dump(model_fit, "models/energy_sarima_model.pkl")
# Out:
# ['models/energy_sarima_model.pkl']

# %%
forecast = model_fit.forecast(steps=30)

# %%
next_month_consumption = forecast.sum()

print("Predicted next month energy:", (next_month_consumption*20)/1000)
# Out:
# Predicted next month energy: 865.226224234003
